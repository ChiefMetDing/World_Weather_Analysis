# %%
# Import the dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from citipy import citipy
# Import the requests library
import requests
import json

# Import the API key
from config import weather_api_key
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high = 180.000,size = 2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list of holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 755

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval    ")
print("----------------------------")

# Create counters.
record_count = 1
set_count = 0

# Loop through all the cities in the list
for i,city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 0):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count +=1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # convert the data to ISO standard
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City":city.title(),
                          "Country": city_country,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Current Description": city_description
                         })
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
print("----------------------------")
print("Data Retrieval Complete     ")
print("----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | tual
# Processing Record 4 of Set 1 | yaremche
# Processing Record 5 of Set 1 | kieta
# Processing Record 6 of Set 1 | lagoa
# Processing Record 7 of Set 1 | barinas
# Processing Record 8 of Set 1 | macusani
# Processing Record 9 of Set 1 | bischwiller
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | dikson
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | hermanus
# Processing Record 14 of Set 1 | new norfolk
# Processing Record 15 of Set 1 | erenhot
# Processing Record 16 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 1 | mocambique
# City not found. Skipping...
# Processing Record 18 of Set 1 | port alfred
# Processing Record 19 of Set 1 | jamestown
# Processing Record 20 of Set 1 | rajampet
# Processing Record 21 of Set 1 | kodiak
# Processing Record 22 of Set 1 | fairbanks
# Processing Record 23 of Set 1 | marfino
# Processing Record 24 of Set 1 | upernavik
# Processing Record 25 of Set 1 | cherskiy
# Processing Record 26 of Set 1 | castro
# Processing Record 27 of Set 1 | tabas
# Processing Record 28 of Set 1 | bengkulu
# Processing Record 29 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 1 | faya
# Processing Record 32 of Set 1 | victoria
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | urumqi
# Processing Record 35 of Set 1 | kapaa
# Processing Record 36 of Set 1 | mitsamiouli
# Processing Record 37 of Set 1 | puerto ayora
# Processing Record 38 of Set 1 | avera
# Processing Record 39 of Set 1 | belyy yar
# Processing Record 40 of Set 1 | iringa
# Processing Record 41 of Set 1 | alofi
# Processing Record 42 of Set 1 | kalakamati
# Processing Record 43 of Set 1 | sao jose da coroa grande
# Processing Record 44 of Set 1 | karwar
# Processing Record 45 of Set 1 | bluff
# Processing Record 46 of Set 1 | mahebourg
# Processing Record 47 of Set 1 | sao mateus
# Processing Record 48 of Set 1 | joshimath
# Processing Record 49 of Set 1 | belmonte
# Processing Record 50 of Set 1 | san quintin
# Processing Record 1 of Set 2 | vaini
# Processing Record 2 of Set 2 | grindavik
# Processing Record 3 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 2 | vaitape
# Processing Record 5 of Set 2 | rikitea
# Processing Record 6 of Set 2 | kot kapura
# Processing Record 7 of Set 2 | filadelfia
# Processing Record 8 of Set 2 | husavik
# Processing Record 9 of Set 2 | kwinana
# Processing Record 10 of Set 2 | saskylakh
# Processing Record 11 of Set 2 | tahoua
# Processing Record 12 of Set 2 | tuktoyaktuk
# Processing Record 13 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 2 | kaniama
# Processing Record 15 of Set 2 | cidreira
# Processing Record 16 of Set 2 | saldanha
# Processing Record 17 of Set 2 | hofn
# Processing Record 18 of Set 2 | yellowknife
# Processing Record 19 of Set 2 | vostok
# Processing Record 20 of Set 2 | tasiilaq
# Processing Record 21 of Set 2 | hilo
# Processing Record 22 of Set 2 | salvador
# Processing Record 23 of Set 2 | brantford
# Processing Record 24 of Set 2 | linxia
# Processing Record 25 of Set 2 | quelimane
# Processing Record 26 of Set 2 | kabinda
# Processing Record 27 of Set 2 | puerto gaitan
# Processing Record 28 of Set 2 | sao filipe
# Processing Record 29 of Set 2 | adrar
# Processing Record 30 of Set 2 | lorengau
# Processing Record 31 of Set 2 | mataura
# Processing Record 32 of Set 2 | berlevag
# Processing Record 33 of Set 2 | codrington
# Processing Record 34 of Set 2 | bowen
# Processing Record 35 of Set 2 | torbay
# Processing Record 36 of Set 2 | santa maria
# Processing Record 37 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 2 | port elizabeth
# Processing Record 39 of Set 2 | urdoma
# Processing Record 40 of Set 2 | coahuayana
# Processing Record 41 of Set 2 | kasempa
# Processing Record 42 of Set 2 | saint-philippe
# Processing Record 43 of Set 2 | cape town
# Processing Record 44 of Set 2 | barrow
# Processing Record 45 of Set 2 | kamaishi
# Processing Record 46 of Set 2 | ijaki
# City not found. Skipping...
# Processing Record 47 of Set 2 | lae
# Processing Record 48 of Set 2 | hadishahr
# Processing Record 49 of Set 2 | nishihara
# Processing Record 50 of Set 2 | tiksi
# Processing Record 1 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 3 | bathsheba
# Processing Record 3 of Set 3 | salzwedel
# Processing Record 4 of Set 3 | atuona
# Processing Record 5 of Set 3 | manono
# Processing Record 6 of Set 3 | bosaso
# Processing Record 7 of Set 3 | samarinda
# Processing Record 8 of Set 3 | svetlogorsk
# Processing Record 9 of Set 3 | bakaly
# Processing Record 10 of Set 3 | caucasia
# Processing Record 11 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 3 | kilindoni
# Processing Record 13 of Set 3 | baiquan
# Processing Record 14 of Set 3 | carnarvon
# Processing Record 15 of Set 3 | bhuban
# Processing Record 16 of Set 3 | wajir
# Processing Record 17 of Set 3 | laguna
# Processing Record 18 of Set 3 | avarua
# Processing Record 19 of Set 3 | narsaq
# Processing Record 20 of Set 3 | evensk
# Processing Record 21 of Set 3 | east london
# Processing Record 22 of Set 3 | necochea
# Processing Record 23 of Set 3 | ndele
# Processing Record 24 of Set 3 | banyo
# Processing Record 25 of Set 3 | sibolga
# Processing Record 26 of Set 3 | mendahara
# City not found. Skipping...
# Processing Record 27 of Set 3 | san lawrenz
# Processing Record 28 of Set 3 | iskateley
# Processing Record 29 of Set 3 | lebu
# Processing Record 30 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 3 | severo-kurilsk
# Processing Record 32 of Set 3 | haines junction
# Processing Record 33 of Set 3 | norman wells
# Processing Record 34 of Set 3 | santa cruz del sur
# Processing Record 35 of Set 3 | ponta do sol
# Processing Record 36 of Set 3 | mar del plata
# Processing Record 37 of Set 3 | arraial do cabo
# Processing Record 38 of Set 3 | pacific grove
# Processing Record 39 of Set 3 | ancud
# Processing Record 40 of Set 3 | yelatma
# Processing Record 41 of Set 3 | namibe
# Processing Record 42 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 3 | lasa
# Processing Record 44 of Set 3 | baiao
# Processing Record 45 of Set 3 | ballina
# Processing Record 46 of Set 3 | nuuk
# Processing Record 47 of Set 3 | kaitangata
# Processing Record 48 of Set 3 | tessalit
# Processing Record 49 of Set 3 | khatanga
# Processing Record 50 of Set 3 | vilsbiburg
# Processing Record 1 of Set 4 | butaritari
# Processing Record 2 of Set 4 | esperance
# Processing Record 3 of Set 4 | eyl
# Processing Record 4 of Set 4 | mo i rana
# Processing Record 5 of Set 4 | pangnirtung
# Processing Record 6 of Set 4 | loukhi
# Processing Record 7 of Set 4 | amberley
# Processing Record 8 of Set 4 | novopokrovka
# Processing Record 9 of Set 4 | nizhniy odes
# Processing Record 10 of Set 4 | asfi
# Processing Record 11 of Set 4 | sao joao da barra
# Processing Record 12 of Set 4 | wageningen
# Processing Record 13 of Set 4 | cabo san lucas
# Processing Record 14 of Set 4 | bredasdorp
# Processing Record 15 of Set 4 | conde
# Processing Record 16 of Set 4 | zhireken
# Processing Record 17 of Set 4 | saint george
# Processing Record 18 of Set 4 | talnakh
# Processing Record 19 of Set 4 | kilcullen
# Processing Record 20 of Set 4 | khagaria
# Processing Record 21 of Set 4 | yabassi
# Processing Record 22 of Set 4 | ugoofaaru
# Processing Record 23 of Set 4 | souillac
# Processing Record 24 of Set 4 | port lincoln
# Processing Record 25 of Set 4 | cairns
# Processing Record 26 of Set 4 | naze
# Processing Record 27 of Set 4 | deputatskiy
# Processing Record 28 of Set 4 | bobon
# Processing Record 29 of Set 4 | anadyr
# Processing Record 30 of Set 4 | faanui
# Processing Record 31 of Set 4 | bakel
# Processing Record 32 of Set 4 | ostrovnoy
# Processing Record 33 of Set 4 | nhulunbuy
# Processing Record 34 of Set 4 | kimbe
# Processing Record 35 of Set 4 | santa cruz
# Processing Record 36 of Set 4 | axim
# Processing Record 37 of Set 4 | mhlume
# Processing Record 38 of Set 4 | leningradskiy
# Processing Record 39 of Set 4 | san cristobal
# Processing Record 40 of Set 4 | saint-joseph
# Processing Record 41 of Set 4 | hithadhoo
# Processing Record 42 of Set 4 | paita
# Processing Record 43 of Set 4 | ixtapa
# Processing Record 44 of Set 4 | ha noi
# Processing Record 45 of Set 4 | sinnamary
# Processing Record 46 of Set 4 | santana do mundau
# Processing Record 47 of Set 4 | ahuimanu
# Processing Record 48 of Set 4 | asau
# Processing Record 49 of Set 4 | fjerritslev
# Processing Record 50 of Set 4 | georgetown
# Processing Record 1 of Set 5 | ust-ishim
# Processing Record 2 of Set 5 | raudeberg
# Processing Record 3 of Set 5 | olafsvik
# Processing Record 4 of Set 5 | zholymbet
# Processing Record 5 of Set 5 | edson
# Processing Record 6 of Set 5 | longyearbyen
# Processing Record 7 of Set 5 | biloela
# Processing Record 8 of Set 5 | hasaki
# Processing Record 9 of Set 5 | touros
# Processing Record 10 of Set 5 | salalah
# Processing Record 11 of Set 5 | kirando
# Processing Record 12 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 5 | yumen
# Processing Record 14 of Set 5 | khandyga
# Processing Record 15 of Set 5 | cockburn town
# Processing Record 16 of Set 5 | resistencia
# Processing Record 17 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 18 of Set 5 | cayenne
# Processing Record 19 of Set 5 | talant
# Processing Record 20 of Set 5 | roebourne
# Processing Record 21 of Set 5 | ribeira grande
# Processing Record 22 of Set 5 | dunedin
# Processing Record 23 of Set 5 | thompson
# Processing Record 24 of Set 5 | aparecida do taboado
# Processing Record 25 of Set 5 | bababe
# City not found. Skipping...
# Processing Record 26 of Set 5 | maniitsoq
# Processing Record 27 of Set 5 | khormuj
# City not found. Skipping...
# Processing Record 28 of Set 5 | manakara
# Processing Record 29 of Set 5 | bac lieu
# Processing Record 30 of Set 5 | punta gorda
# Processing Record 31 of Set 5 | puerto escondido
# Processing Record 32 of Set 5 | jurado
# Processing Record 33 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 5 | clyde river
# Processing Record 35 of Set 5 | mandalgovi
# Processing Record 36 of Set 5 | boa vista
# Processing Record 37 of Set 5 | san buenaventura
# Processing Record 38 of Set 5 | ternate
# Processing Record 39 of Set 5 | saint-pierre
# Processing Record 40 of Set 5 | verkhoyansk
# Processing Record 41 of Set 5 | tuy hoa
# Processing Record 42 of Set 5 | qaanaaq
# Processing Record 43 of Set 5 | walla walla
# Processing Record 44 of Set 5 | nanning
# Processing Record 45 of Set 5 | klaksvik
# Processing Record 46 of Set 5 | pankrushikha
# Processing Record 47 of Set 5 | yongan
# Processing Record 48 of Set 5 | fuerte olimpo
# Processing Record 49 of Set 5 | qasigiannguit
# Processing Record 50 of Set 5 | imperia
# Processing Record 1 of Set 6 | ngozi
# Processing Record 2 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 3 of Set 6 | yook
# Processing Record 4 of Set 6 | elizabeth city
# Processing Record 5 of Set 6 | beringovskiy
# Processing Record 6 of Set 6 | astana
# Processing Record 7 of Set 6 | rawson
# Processing Record 8 of Set 6 | pevek
# Processing Record 9 of Set 6 | noyabrsk
# Processing Record 10 of Set 6 | geraldton
# Processing Record 11 of Set 6 | great falls
# Processing Record 12 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 13 of Set 6 | provideniya
# Processing Record 14 of Set 6 | ruidoso
# Processing Record 15 of Set 6 | manaure
# Processing Record 16 of Set 6 | bilma
# Processing Record 17 of Set 6 | thisted
# Processing Record 18 of Set 6 | moranbah
# Processing Record 19 of Set 6 | vao
# Processing Record 20 of Set 6 | singleton
# Processing Record 21 of Set 6 | sterling
# Processing Record 22 of Set 6 | barra patuca
# Processing Record 23 of Set 6 | praia da vitoria
# Processing Record 24 of Set 6 | bloemhof
# Processing Record 25 of Set 6 | vidalia
# Processing Record 26 of Set 6 | margate
# Processing Record 27 of Set 6 | te anau
# Processing Record 28 of Set 6 | fortuna
# Processing Record 29 of Set 6 | kondoa
# Processing Record 30 of Set 6 | dubenskiy
# City not found. Skipping...
# Processing Record 31 of Set 6 | izhma
# Processing Record 32 of Set 6 | nome
# Processing Record 33 of Set 6 | byron bay
# Processing Record 34 of Set 6 | maltahohe
# Processing Record 35 of Set 6 | gurupa
# Processing Record 36 of Set 6 | bethel
# Processing Record 37 of Set 6 | pochutla
# Processing Record 38 of Set 6 | baykit
# Processing Record 39 of Set 6 | shellbrook
# Processing Record 40 of Set 6 | gamba
# Processing Record 41 of Set 6 | san juan
# Processing Record 42 of Set 6 | okha
# Processing Record 43 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 6 | oktyabrskiy
# Processing Record 45 of Set 6 | san alberto
# Processing Record 46 of Set 6 | korla
# Processing Record 47 of Set 6 | soe
# Processing Record 48 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 6 | la macarena
# Processing Record 50 of Set 6 | san antonio
# Processing Record 1 of Set 7 | castelo do piaui
# Processing Record 2 of Set 7 | ayni
# Processing Record 3 of Set 7 | chauk
# Processing Record 4 of Set 7 | hukuntsi
# Processing Record 5 of Set 7 | tigil
# Processing Record 6 of Set 7 | telde
# Processing Record 7 of Set 7 | shulan
# Processing Record 8 of Set 7 | rudbar
# Processing Record 9 of Set 7 | kardla
# Processing Record 10 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 7 | marzuq
# Processing Record 12 of Set 7 | beruwala
# Processing Record 13 of Set 7 | mount pleasant
# Processing Record 14 of Set 7 | port-gentil
# Processing Record 15 of Set 7 | college
# Processing Record 16 of Set 7 | vila franca do campo
# Processing Record 17 of Set 7 | saint-georges
# Processing Record 18 of Set 7 | djambala
# Processing Record 19 of Set 7 | las vegas
# Processing Record 20 of Set 7 | berezovyy
# Processing Record 21 of Set 7 | okhotsk
# Processing Record 22 of Set 7 | bambous virieux
# Processing Record 23 of Set 7 | kenai
# Processing Record 24 of Set 7 | nouadhibou
# Processing Record 25 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 26 of Set 7 | san mateo del mar
# Processing Record 27 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 28 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 7 | kolosovka
# Processing Record 30 of Set 7 | hammerfest
# Processing Record 31 of Set 7 | melioratorov
# Processing Record 32 of Set 7 | hashtrud
# Processing Record 33 of Set 7 | port macquarie
# Processing Record 34 of Set 7 | hambantota
# Processing Record 35 of Set 7 | chokurdakh
# Processing Record 36 of Set 7 | carutapera
# Processing Record 37 of Set 7 | chit baragaon
# City not found. Skipping...
# Processing Record 38 of Set 7 | voyskovitsy
# Processing Record 39 of Set 7 | poum
# Processing Record 40 of Set 7 | chuy
# Processing Record 41 of Set 7 | chebenki
# Processing Record 42 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 43 of Set 7 | dwarka
# Processing Record 44 of Set 7 | goderich
# Processing Record 45 of Set 7 | atar
# Processing Record 46 of Set 7 | eureka
# Processing Record 47 of Set 7 | la crosse
# Processing Record 48 of Set 7 | lompoc
# Processing Record 49 of Set 7 | imbituba
# Processing Record 50 of Set 7 | plettenberg bay
# Processing Record 1 of Set 8 | oktyabrskoye
# Processing Record 2 of Set 8 | port hardy
# Processing Record 3 of Set 8 | inhambane
# Processing Record 4 of Set 8 | mingaora
# Processing Record 5 of Set 8 | ahipara
# Processing Record 6 of Set 8 | teguldet
# Processing Record 7 of Set 8 | muros
# Processing Record 8 of Set 8 | havoysund
# Processing Record 9 of Set 8 | qunduz
# Processing Record 10 of Set 8 | anderson
# Processing Record 11 of Set 8 | guiratinga
# Processing Record 12 of Set 8 | coromandel
# Processing Record 13 of Set 8 | loandjili
# Processing Record 14 of Set 8 | mackay
# Processing Record 15 of Set 8 | izumo
# Processing Record 16 of Set 8 | ellisras
# Processing Record 17 of Set 8 | khuzdar
# Processing Record 18 of Set 8 | yulara
# Processing Record 19 of Set 8 | katsuura
# Processing Record 20 of Set 8 | bustamante
# Processing Record 21 of Set 8 | nanortalik
# Processing Record 22 of Set 8 | bokoro
# Processing Record 23 of Set 8 | okato
# Processing Record 24 of Set 8 | cazaje
# City not found. Skipping...
# Processing Record 25 of Set 8 | santa maria del oro
# Processing Record 26 of Set 8 | airai
# Processing Record 27 of Set 8 | tsabong
# Processing Record 28 of Set 8 | kahului
# Processing Record 29 of Set 8 | grand gaube
# Processing Record 30 of Set 8 | kolokani
# Processing Record 31 of Set 8 | tiznit
# Processing Record 32 of Set 8 | falealupo
# City not found. Skipping...
# Processing Record 33 of Set 8 | vetluga
# Processing Record 34 of Set 8 | mount gambier
# Processing Record 35 of Set 8 | sur
# Processing Record 36 of Set 8 | mingguang
# Processing Record 37 of Set 8 | khani
# Processing Record 38 of Set 8 | cerrito
# Processing Record 39 of Set 8 | mikhaylovka
# Processing Record 40 of Set 8 | kindia
# Processing Record 41 of Set 8 | tomatlan
# Processing Record 42 of Set 8 | jumla
# Processing Record 43 of Set 8 | oussouye
# Processing Record 44 of Set 8 | zavallya
# Processing Record 45 of Set 8 | westport
# Processing Record 46 of Set 8 | nogliki
# Processing Record 47 of Set 8 | luderitz
# Processing Record 48 of Set 8 | coihaique
# Processing Record 49 of Set 8 | marsa matruh
# Processing Record 50 of Set 8 | sayyan
# Processing Record 1 of Set 9 | davila
# Processing Record 2 of Set 9 | port blair
# Processing Record 3 of Set 9 | rio gallegos
# Processing Record 4 of Set 9 | ambodifototra
# City not found. Skipping...
# Processing Record 5 of Set 9 | north bend
# Processing Record 6 of Set 9 | rassvet
# Processing Record 7 of Set 9 | sabha
# Processing Record 8 of Set 9 | lerwick
# Processing Record 9 of Set 9 | iqaluit
# Processing Record 10 of Set 9 | zaraza
# Processing Record 11 of Set 9 | sovetskiy
# Processing Record 12 of Set 9 | nagua
# Processing Record 13 of Set 9 | khorixas
# Processing Record 14 of Set 9 | porto novo
# Processing Record 15 of Set 9 | salug
# Processing Record 16 of Set 9 | lavrentiya
# Processing Record 17 of Set 9 | zheleznodorozhnyy
# Processing Record 18 of Set 9 | berja
# Processing Record 19 of Set 9 | nakusp
# Processing Record 20 of Set 9 | yarkovo
# Processing Record 21 of Set 9 | raxaul
# Processing Record 22 of Set 9 | pisco
# Processing Record 23 of Set 9 | awbari
# Processing Record 24 of Set 9 | pimenta bueno
# Processing Record 25 of Set 9 | emmauss
# Processing Record 26 of Set 9 | surt
# Processing Record 27 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 28 of Set 9 | asosa
# Processing Record 29 of Set 9 | ibanda
# Processing Record 30 of Set 9 | erdenet
# Processing Record 31 of Set 9 | padang
# Processing Record 32 of Set 9 | jinchang
# Processing Record 33 of Set 9 | odessa
# Processing Record 34 of Set 9 | jensen beach
# Processing Record 35 of Set 9 | nikolskoye
# Processing Record 36 of Set 9 | manjacaze
# Processing Record 37 of Set 9 | tabuk
# Processing Record 38 of Set 9 | rioblanco
# Processing Record 39 of Set 9 | hay river
# Processing Record 40 of Set 9 | gat
# Processing Record 41 of Set 9 | tommot
# Processing Record 42 of Set 9 | sisimiut
# Processing Record 43 of Set 9 | poronaysk
# Processing Record 44 of Set 9 | myitkyina
# Processing Record 45 of Set 9 | kruisfontein
# Processing Record 46 of Set 9 | talcahuano
# Processing Record 47 of Set 9 | la ronge
# Processing Record 48 of Set 9 | forestville
# Processing Record 49 of Set 9 | chaa-khol
# City not found. Skipping...
# Processing Record 50 of Set 9 | svarstad
# Processing Record 1 of Set 10 | xichang
# Processing Record 2 of Set 10 | beian
# Processing Record 3 of Set 10 | constitucion
# Processing Record 4 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 5 of Set 10 | mananjary
# Processing Record 6 of Set 10 | labuan
# Processing Record 7 of Set 10 | iquique
# Processing Record 8 of Set 10 | decs
# Processing Record 9 of Set 10 | ulladulla
# Processing Record 10 of Set 10 | hovd
# Processing Record 11 of Set 10 | koslan
# Processing Record 12 of Set 10 | puerto baquerizo moreno
# Processing Record 13 of Set 10 | amiens
# Processing Record 14 of Set 10 | tuatapere
# Processing Record 15 of Set 10 | namtsy
# Processing Record 16 of Set 10 | bajil
# Processing Record 17 of Set 10 | pokrovskoye
# Processing Record 18 of Set 10 | taltal
# Processing Record 19 of Set 10 | urengoy
# Processing Record 20 of Set 10 | kedrovyy
# Processing Record 21 of Set 10 | sangar
# Processing Record 22 of Set 10 | coquimbo
# Processing Record 23 of Set 10 | severnyy
# Processing Record 24 of Set 10 | baykalsk
# Processing Record 25 of Set 10 | ambilobe
# Processing Record 26 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 27 of Set 10 | acheng
# Processing Record 28 of Set 10 | saint anthony
# Processing Record 29 of Set 10 | maghama
# City not found. Skipping...
# Processing Record 30 of Set 10 | half moon bay
# Processing Record 31 of Set 10 | dalbandin
# Processing Record 32 of Set 10 | palauig
# Processing Record 33 of Set 10 | xiongyue
# Processing Record 34 of Set 10 | comodoro rivadavia
# Processing Record 35 of Set 10 | giresun
# Processing Record 36 of Set 10 | obo
# Processing Record 37 of Set 10 | zhigansk
# Processing Record 38 of Set 10 | sept-iles
# Processing Record 39 of Set 10 | camrose
# Processing Record 40 of Set 10 | bonavista
# Processing Record 41 of Set 10 | marawi
# Processing Record 42 of Set 10 | tura
# Processing Record 43 of Set 10 | tazovskiy
# Processing Record 44 of Set 10 | bara
# Processing Record 45 of Set 10 | sepolno krajenskie
# Processing Record 46 of Set 10 | batagay-alyta
# Processing Record 47 of Set 10 | yantal
# Processing Record 48 of Set 10 | san jose
# Processing Record 49 of Set 10 | izazi
# Processing Record 50 of Set 10 | springbok
# Processing Record 1 of Set 11 | kununurra
# Processing Record 2 of Set 11 | varzea da palma
# Processing Record 3 of Set 11 | shache
# Processing Record 4 of Set 11 | aswan
# Processing Record 5 of Set 11 | nantucket
# Processing Record 6 of Set 11 | bakchar
# Processing Record 7 of Set 11 | yala
# Processing Record 8 of Set 11 | grants
# Processing Record 9 of Set 11 | la cruz
# Processing Record 10 of Set 11 | sainte-agathe-des-monts
# Processing Record 11 of Set 11 | sudak
# Processing Record 12 of Set 11 | belle fourche
# Processing Record 13 of Set 11 | miramar
# Processing Record 14 of Set 11 | sri aman
# Processing Record 15 of Set 11 | wanaka
# Processing Record 16 of Set 11 | tamandare
# Processing Record 17 of Set 11 | vila velha
# Processing Record 18 of Set 11 | andapa
# Processing Record 19 of Set 11 | ust-maya
# Processing Record 20 of Set 11 | big spring
# Processing Record 21 of Set 11 | boljarovo
# City not found. Skipping...
# Processing Record 22 of Set 11 | gushikawa
# Processing Record 23 of Set 11 | reichenbach
# Processing Record 24 of Set 11 | kautokeino
# Processing Record 25 of Set 11 | minna
# Processing Record 26 of Set 11 | sibu
# Processing Record 27 of Set 11 | nova olimpia
# Processing Record 28 of Set 11 | verkhniy mamon
# Processing Record 29 of Set 11 | komsomolskiy
# Processing Record 30 of Set 11 | bitlis
# Processing Record 31 of Set 11 | gampaha
# Processing Record 32 of Set 11 | tshikapa
# Processing Record 33 of Set 11 | birao
# Processing Record 34 of Set 11 | morehead
# Processing Record 35 of Set 11 | hualmay
# Processing Record 36 of Set 11 | mergui
# City not found. Skipping...
# Processing Record 37 of Set 11 | rio verde de mato grosso
# Processing Record 38 of Set 11 | matara
# Processing Record 39 of Set 11 | pemangkat
# Processing Record 40 of Set 11 | salym
# Processing Record 41 of Set 11 | caravelas
# Processing Record 42 of Set 11 | fort abbas
# Processing Record 43 of Set 11 | vorotynets
# Processing Record 44 of Set 11 | kindu
# Processing Record 45 of Set 11 | quatre cocos
# Processing Record 46 of Set 11 | hermosillo
# Processing Record 47 of Set 11 | asmara
# Processing Record 48 of Set 11 | vuktyl
# Processing Record 49 of Set 11 | cutro
# Processing Record 50 of Set 11 | bida
# Processing Record 1 of Set 12 | bonthe
# Processing Record 2 of Set 12 | nelson bay
# Processing Record 3 of Set 12 | pringsewu
# Processing Record 4 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 5 of Set 12 | hellvik
# Processing Record 6 of Set 12 | sola
# Processing Record 7 of Set 12 | sapao
# City not found. Skipping...
# Processing Record 8 of Set 12 | cotonou
# Processing Record 9 of Set 12 | paamiut
# Processing Record 10 of Set 12 | harper
# Processing Record 11 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 12 of Set 12 | shenjiamen
# Processing Record 13 of Set 12 | ketchikan
# Processing Record 14 of Set 12 | fare
# Processing Record 15 of Set 12 | alice springs
# Processing Record 16 of Set 12 | hebertville
# City not found. Skipping...
# Processing Record 17 of Set 12 | shubarshi
# Processing Record 18 of Set 12 | kawalu
# Processing Record 19 of Set 12 | sovetskaya gavan
# Processing Record 20 of Set 12 | solnechnyy
# Processing Record 21 of Set 12 | broome
# Processing Record 22 of Set 12 | kiomboi
# Processing Record 23 of Set 12 | atambua
# Processing Record 24 of Set 12 | hervey bay
# Processing Record 25 of Set 12 | montepuez
# Processing Record 26 of Set 12 | odienne
# Processing Record 27 of Set 12 | diamantino
# Processing Record 28 of Set 12 | hamilton
# Processing Record 29 of Set 12 | wad madani
# Processing Record 30 of Set 12 | port hawkesbury
# Processing Record 31 of Set 12 | panaba
# Processing Record 32 of Set 12 | ilulissat
# Processing Record 33 of Set 12 | rocky mountain house
# Processing Record 34 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 35 of Set 12 | washougal
# Processing Record 36 of Set 12 | marsh harbour
# Processing Record 37 of Set 12 | kichera
# Processing Record 38 of Set 12 | port augusta
# Processing Record 39 of Set 12 | flinders
# Processing Record 40 of Set 12 | kavieng
# Processing Record 41 of Set 12 | thilogne
# City not found. Skipping...
# Processing Record 42 of Set 12 | dudinka
# Processing Record 43 of Set 12 | azangaro
# Processing Record 44 of Set 12 | malkapur
# Processing Record 45 of Set 12 | guerrero negro
# Processing Record 46 of Set 12 | nioro
# Processing Record 47 of Set 12 | xadani
# City not found. Skipping...
# Processing Record 48 of Set 12 | petawawa
# Processing Record 49 of Set 12 | seoul
# Processing Record 50 of Set 12 | walvis bay
# Processing Record 1 of Set 13 | lac du bonnet
# Processing Record 2 of Set 13 | fossano
# Processing Record 3 of Set 13 | vanimo
# Processing Record 4 of Set 13 | borgarnes
# Processing Record 5 of Set 13 | buala
# Processing Record 6 of Set 13 | lazaro cardenas
# Processing Record 7 of Set 13 | sokolo
# Processing Record 8 of Set 13 | vardo
# Processing Record 9 of Set 13 | strezhevoy
# Processing Record 10 of Set 13 | pontes e lacerda
# Processing Record 11 of Set 13 | tungkang
# City not found. Skipping...
# Processing Record 12 of Set 13 | hoi an
# Processing Record 13 of Set 13 | umm kaddadah
# Processing Record 14 of Set 13 | palmer
# Processing Record 15 of Set 13 | praya
# Processing Record 16 of Set 13 | pontianak
# Processing Record 17 of Set 13 | arman
# Processing Record 18 of Set 13 | askiz
# Processing Record 19 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 13 | moutier
# Processing Record 21 of Set 13 | cheney
# Processing Record 22 of Set 13 | itarema
# Processing Record 23 of Set 13 | el paso
# Processing Record 24 of Set 13 | pudozh
# Processing Record 25 of Set 13 | setermoen
# Processing Record 26 of Set 13 | lucapa
# Processing Record 27 of Set 13 | salinopolis
# Processing Record 28 of Set 13 | shelburne
# Processing Record 29 of Set 13 | champerico
# Processing Record 30 of Set 13 | kalanwali
# Processing Record 31 of Set 13 | sakakah
# Processing Record 32 of Set 13 | yakeshi
# Processing Record 33 of Set 13 | oksfjord
# Processing Record 34 of Set 13 | vung tau
# Processing Record 35 of Set 13 | sorland
# Processing Record 36 of Set 13 | puri
# Processing Record 37 of Set 13 | qaqortoq
# Processing Record 38 of Set 13 | gargzdai
# Processing Record 39 of Set 13 | mancio lima
# Processing Record 40 of Set 13 | mayo
# Processing Record 41 of Set 13 | salisbury
# Processing Record 42 of Set 13 | barranca
# Processing Record 43 of Set 13 | presidente epitacio
# Processing Record 44 of Set 13 | metro
# Processing Record 45 of Set 13 | huainan
# Processing Record 46 of Set 13 | sesheke
# Processing Record 47 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 48 of Set 13 | ust-kuyga
# Processing Record 49 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 50 of Set 13 | plouzane
# Processing Record 1 of Set 14 | chapais
# Processing Record 2 of Set 14 | hirara
# Processing Record 3 of Set 14 | borovskoy
# Processing Record 4 of Set 14 | kavaratti
# Processing Record 5 of Set 14 | itoman
# Processing Record 6 of Set 14 | kathu
# Processing Record 7 of Set 14 | zvishavane
# Processing Record 8 of Set 14 | belousovka
# Processing Record 9 of Set 14 | fort wellington
# Processing Record 10 of Set 14 | paros
# Processing Record 11 of Set 14 | nam tha
# City not found. Skipping...
# Processing Record 12 of Set 14 | labuhan
# Processing Record 13 of Set 14 | newport
# Processing Record 14 of Set 14 | privolnyy
# Processing Record 15 of Set 14 | upata
# Processing Record 16 of Set 14 | nizhniy chir
# Processing Record 17 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 14 | kon tum
# Processing Record 19 of Set 14 | akcaabat
# Processing Record 20 of Set 14 | fomboni
# Processing Record 21 of Set 14 | kuva
# City not found. Skipping...
# Processing Record 22 of Set 14 | salta
# Processing Record 23 of Set 14 | bacuit
# City not found. Skipping...
# Processing Record 24 of Set 14 | tianpeng
# Processing Record 25 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 26 of Set 14 | kulgam
# Processing Record 27 of Set 14 | kilgore
# Processing Record 28 of Set 14 | kaeo
# Processing Record 29 of Set 14 | antofagasta
# Processing Record 30 of Set 14 | conceicao do araguaia
# Processing Record 31 of Set 14 | nyuksenitsa
# Processing Record 32 of Set 14 | aguimes
# Processing Record 33 of Set 14 | chabahar
# Processing Record 34 of Set 14 | pustoshka
# Processing Record 35 of Set 14 | moscow
# Processing Record 36 of Set 14 | kannur
# Processing Record 37 of Set 14 | aitape
# Processing Record 38 of Set 14 | andarab
# City not found. Skipping...
# Processing Record 39 of Set 14 | kudahuvadhoo
# Processing Record 40 of Set 14 | peniche
# Processing Record 41 of Set 14 | ulaanbaatar
# Processing Record 42 of Set 14 | oytal
# Processing Record 43 of Set 14 | reconquista
# Processing Record 44 of Set 14 | state college
# Processing Record 45 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 14 | agadez
# Processing Record 47 of Set 14 | krasnyy chikoy
# Processing Record 48 of Set 14 | uren
# Processing Record 49 of Set 14 | jega
# Processing Record 50 of Set 14 | viedma
# Processing Record 1 of Set 15 | oistins
# Processing Record 2 of Set 15 | pascagoula
# Processing Record 3 of Set 15 | najran
# Processing Record 4 of Set 15 | naron
# Processing Record 5 of Set 15 | manadhoo
# Processing Record 6 of Set 15 | vila do maio
# Processing Record 7 of Set 15 | cururupu
# Processing Record 8 of Set 15 | chatham
# Processing Record 9 of Set 15 | sioux lookout
# Processing Record 10 of Set 15 | igdir
# Processing Record 11 of Set 15 | ponta delgada
# Processing Record 12 of Set 15 | kloulklubed
# Processing Record 13 of Set 15 | fayaoue
# Processing Record 14 of Set 15 | lata
# Processing Record 15 of Set 15 | meulaboh
# Processing Record 16 of Set 15 | cap malheureux
# Processing Record 17 of Set 15 | inta
# Processing Record 18 of Set 15 | magdagachi
# Processing Record 19 of Set 15 | nusaybin
# Processing Record 20 of Set 15 | saint-leu
# Processing Record 21 of Set 15 | chara
# Processing Record 22 of Set 15 | trofors
# Processing Record 23 of Set 15 | jauharabad
# Processing Record 24 of Set 15 | beloha
# Processing Record 25 of Set 15 | kalemie
# Processing Record 26 of Set 15 | coruripe
# Processing Record 27 of Set 15 | garachine
# Processing Record 28 of Set 15 | isangel
# Processing Record 29 of Set 15 | kiunga
# Processing Record 30 of Set 15 | ariquemes
# Processing Record 31 of Set 15 | camopi
# Processing Record 32 of Set 15 | beira
# Processing Record 33 of Set 15 | weinan
# Processing Record 34 of Set 15 | tonj
# Processing Record 35 of Set 15 | yeppoon
# Processing Record 36 of Set 15 | zyryanka
# Processing Record 37 of Set 15 | awjilah
# Processing Record 38 of Set 15 | qeshm
# Processing Record 39 of Set 15 | nouakchott
# Processing Record 40 of Set 15 | shunyi
# Processing Record 41 of Set 15 | lamas
# Processing Record 42 of Set 15 | cumaribo
# City not found. Skipping...
# Processing Record 43 of Set 15 | catuday
# Processing Record 44 of Set 15 | santa rosa
# Processing Record 45 of Set 15 | taoudenni
# Processing Record 46 of Set 15 | nemuro
# Processing Record 47 of Set 15 | starkville
# Processing Record 48 of Set 15 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 49 of Set 15 | ambulu
# Processing Record 50 of Set 15 | dingle
# Processing Record 1 of Set 16 | uribia
# Processing Record 2 of Set 16 | leova
# Processing Record 3 of Set 16 | posevnaya
# Processing Record 4 of Set 16 | la baneza
# Processing Record 5 of Set 16 | lachi
# ----------------------------
# Data Retrieval Complete
# ----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Punta Arenas      CL -53.1500  -70.9167      8.00        76          40
# 1          Hobart      AU -42.8794  147.3294     17.00        51          40
# 2            Tual      ID  -5.6667  132.7500     28.17        72          99
# 3        Yaremche      UA  48.4583   24.5519     11.00        32          75
# 4           Kieta      PG  -6.2167  155.6333     26.33        86          95
# ..            ...     ...      ...       ...       ...       ...         ...
# 691        Uribia      CO  11.7139  -72.2660     30.73        52          99
# 692         Leova      MD  46.4786   28.2553     11.31        48         100
# 693     Posevnaya      RU  54.3006   83.3297     -4.93        93          98
# 694     La Baneza      ES  42.3003   -5.8977     22.78        25          20
# 695         Lachi      PK  33.3833   71.3386     24.00        23          40
#
#      Wind Speed Current Description
# 0         14.92    scattered clouds
# 1          5.14    scattered clouds
# 2          2.31     overcast clouds
# 3          2.00       broken clouds
# 4          1.63          light rain
# ..          ...                 ...
# 691        8.71     overcast clouds
# 692        2.32          light rain
# 693        3.16     overcast clouds
# 694        5.66          few clouds
# 695        1.45                haze
#
# [696 rows x 9 columns]

# %%
# Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label = "City_ID")
